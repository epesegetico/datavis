# %%
import pandas as pd
import matplotlib.pyplot as plt
import io
import requests

# %%
url = 'https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-andamento-nazionale/dpc-covid19-ita-andamento-nazionale.csv'
s=requests.get(url).content
df = pd.read_csv(io.StringIO(s.decode('UTF-8')),parse_dates = ['data'],index_col='data')

# %%
dates = pd.date_range('20200101',periods = 8)
dates
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.head()
# Out:
#                     stato  ricoverati_con_sintomi  terapia_intensiva  \
# data
# 2020-02-24 18:00:00   ITA                     101                 26
# 2020-02-25 18:00:00   ITA                     114                 35
# 2020-02-26 18:00:00   ITA                     128                 36
# 2020-02-27 18:00:00   ITA                     248                 56
# 2020-02-28 18:00:00   ITA                     345                 64
#
#                      totale_ospedalizzati  isolamento_domiciliare  \
# data
# 2020-02-24 18:00:00                   127                      94
# 2020-02-25 18:00:00                   150                     162
# 2020-02-26 18:00:00                   164                     221
# 2020-02-27 18:00:00                   304                     284
# 2020-02-28 18:00:00                   409                     412
#
#                      totale_attualmente_positivi  nuovi_attualmente_positivi  \
# data
# ...

# %%
df.tail()
# Out:
#                     stato  ricoverati_con_sintomi  terapia_intensiva  \
# data
# 2020-03-13 17:00:00   ITA                    7426               1328
# 2020-03-14 17:00:00   ITA                    8372               1518
# 2020-03-15 17:00:00   ITA                    9663               1672
# 2020-03-16 17:00:00   ITA                   11025               1851
# 2020-03-17 17:00:00   ITA                   12894               2060
#
#                      totale_ospedalizzati  isolamento_domiciliare  \
# data
# 2020-03-13 17:00:00                  8754                    6201
# 2020-03-14 17:00:00                  9890                    7860
# 2020-03-15 17:00:00                 11335                    9268
# 2020-03-16 17:00:00                 12876                   10197
# 2020-03-17 17:00:00                 14954                   11108
#
#                      totale_attualmente_positivi  nuovi_attualmente_positivi  \
# data
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2020-02-24 18:00:00', '2020-02-25 18:00:00',
#                '2020-02-26 18:00:00', '2020-02-27 18:00:00',
#                '2020-02-28 18:00:00', '2020-02-29 18:00:00',
#                '2020-03-01 18:00:00', '2020-03-02 18:00:00',
#                '2020-03-03 18:00:00', '2020-03-04 18:00:00',
#                '2020-03-05 18:00:00', '2020-03-06 18:00:00',
#                '2020-03-07 18:00:00', '2020-03-08 18:00:00',
#                '2020-03-09 18:00:00', '2020-03-10 18:00:00',
#                '2020-03-11 17:00:00', '2020-03-12 17:00:00',
#                '2020-03-13 17:00:00', '2020-03-14 17:00:00',
#                '2020-03-15 17:00:00', '2020-03-16 17:00:00',
#                '2020-03-17 17:00:00'],
#               dtype='datetime64[ns]', name='data', freq=None)

# %%
df.columns
# Out:
# Index(['stato', 'ricoverati_con_sintomi', 'terapia_intensiva',
#        'totale_ospedalizzati', 'isolamento_domiciliare',
#        'totale_attualmente_positivi', 'nuovi_attualmente_positivi',
#        'dimessi_guariti', 'deceduti', 'totale_casi', 'tamponi'],
#       dtype='object')

# %%
# statistiche sul DataFrame
df.describe()
# Out:
#        ricoverati_con_sintomi  terapia_intensiva  totale_ospedalizzati  \
# count               23.000000          23.000000             23.000000
# mean              3770.086957         669.652174           4439.782609
# std               3900.195845         646.691974           4545.606900
# min                101.000000          26.000000            127.000000
# 25%                520.000000         122.500000            642.500000
# 50%               2394.000000         462.000000           2856.000000
# 75%               6244.000000        1090.500000           7334.500000
# max              12894.000000        2060.000000          14954.000000
#
#        isolamento_domiciliare  totale_attualmente_positivi  \
# count               23.000000                    23.000000
# mean              3072.739130                  7512.478261
# std               3475.924837                  7986.594057
# min                 94.000000                   221.000000
# ...

# %%
# Selezionare una colonna
df['terapia_intensiva']
# Out:
# data
# 2020-02-24 18:00:00      26
# 2020-02-25 18:00:00      35
# 2020-02-26 18:00:00      36
# 2020-02-27 18:00:00      56
# 2020-02-28 18:00:00      64
# 2020-02-29 18:00:00     105
# 2020-03-01 18:00:00     140
# 2020-03-02 18:00:00     166
# 2020-03-03 18:00:00     229
# 2020-03-04 18:00:00     295
# 2020-03-05 18:00:00     351
# 2020-03-06 18:00:00     462
# 2020-03-07 18:00:00     567
# 2020-03-08 18:00:00     650
# 2020-03-09 18:00:00     733
# 2020-03-10 18:00:00     877
# 2020-03-11 17:00:00    1028
# 2020-03-12 17:00:00    1153
# 2020-03-13 17:00:00    1328
# 2020-03-14 17:00:00    1518
# 2020-03-15 17:00:00    1672
# 2020-03-16 17:00:00    1851
# 2020-03-17 17:00:00    2060
# Name: terapia_intensiva, dtype: int64

# %%
# Selezionare una (o più) righe
df[0:3]
# Out:
#                     stato  ricoverati_con_sintomi  terapia_intensiva  \
# data
# 2020-02-24 18:00:00   ITA                     101                 26
# 2020-02-25 18:00:00   ITA                     114                 35
# 2020-02-26 18:00:00   ITA                     128                 36
#
#                      totale_ospedalizzati  isolamento_domiciliare  \
# data
# 2020-02-24 18:00:00                   127                      94
# 2020-02-25 18:00:00                   150                     162
# 2020-02-26 18:00:00                   164                     221
#
#                      totale_attualmente_positivi  nuovi_attualmente_positivi  \
# data
# 2020-02-24 18:00:00                          221                         221
# 2020-02-25 18:00:00                          311                          90
# 2020-02-26 18:00:00                          385                          74
#
#                      dimessi_guariti  deceduti  totale_casi  tamponi
# data
# ...

# %%
# Selezionare più colonne per etichetta
df.loc[:,['terapia_intensiva','isolamento_domiciliare']]
# Out:
#                      terapia_intensiva  isolamento_domiciliare
# data
# 2020-02-24 18:00:00                 26                      94
# 2020-02-25 18:00:00                 35                     162
# 2020-02-26 18:00:00                 36                     221
# 2020-02-27 18:00:00                 56                     284
# 2020-02-28 18:00:00                 64                     412
# 2020-02-29 18:00:00                105                     543
# 2020-03-01 18:00:00                140                     798
# 2020-03-02 18:00:00                166                     927
# 2020-03-03 18:00:00                229                    1000
# 2020-03-04 18:00:00                295                    1065
# 2020-03-05 18:00:00                351                    1155
# 2020-03-06 18:00:00                462                    1060
# 2020-03-07 18:00:00                567                    1843
# 2020-03-08 18:00:00                650                    2180
# ...

# %%
# Selezionare per posizione
df.iloc[2]
# Out:
# stato                           ITA
# ricoverati_con_sintomi          128
# terapia_intensiva                36
# totale_ospedalizzati            164
# isolamento_domiciliare          221
# totale_attualmente_positivi     385
# nuovi_attualmente_positivi       74
# dimessi_guariti                   3
# deceduti                         12
# totale_casi                     400
# tamponi                        9587
# Name: 2020-02-26 18:00:00, dtype: object

# %%
# Selezione logica
df[df['deceduti'] > 500]
# Out:
#                     stato  ricoverati_con_sintomi  terapia_intensiva  \
# data
# 2020-03-10 18:00:00   ITA                    5038                877
# 2020-03-11 17:00:00   ITA                    5838               1028
# 2020-03-12 17:00:00   ITA                    6650               1153
# 2020-03-13 17:00:00   ITA                    7426               1328
# 2020-03-14 17:00:00   ITA                    8372               1518
# 2020-03-15 17:00:00   ITA                    9663               1672
# 2020-03-16 17:00:00   ITA                   11025               1851
# 2020-03-17 17:00:00   ITA                   12894               2060
#
#                      totale_ospedalizzati  isolamento_domiciliare  \
# data
# 2020-03-10 18:00:00                  5915                    2599
# 2020-03-11 17:00:00                  6866                    3724
# 2020-03-12 17:00:00                  7803                    5036
# ...

# %%
df.max()
# Out:
# stato                             ITA
# ricoverati_con_sintomi          12894
# terapia_intensiva                2060
# totale_ospedalizzati            14954
# isolamento_domiciliare          11108
# totale_attualmente_positivi     26062
# nuovi_attualmente_positivi       2989
# dimessi_guariti                  2941
# deceduti                         2503
# totale_casi                     31506
# tamponi                        148657
# dtype: object

# %% [markdown]
# # Plotting

# %%
plt.close('all')
plt.figure()
df['totale_attualmente_positivi'].plot()

# %%
df['nuovi_attualmente_positivi'].plot.bar()

# %%
data = df.loc[:,['nuovi_attualmente_positivi','totale_attualmente_positivi']]
plt.figure()
data.plot.bar()

# %%
totale = df['totale_attualmente_positivi']
tendenza = totale.diff()
tendenza.plot()
